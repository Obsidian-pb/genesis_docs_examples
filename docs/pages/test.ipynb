# %%
import osmnx as ox

# %% [markdown]
# Тест ссылки на литературу [@boeing_osmnx_2017].
#
# Тесто.

# %%
#| label: fig-graph
#| fig-cap: "Граф дорожной сети города Железногорска"

G = ox.graph_from_place('Железногорск, Красноярский край, Россия', network_type='drive_service')
ox.plot_graph(G, node_size=0, edge_linewidth=0.2)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
